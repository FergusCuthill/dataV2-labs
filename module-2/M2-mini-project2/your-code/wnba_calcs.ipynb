# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns', 50)

# %%
wnba = pd.read_csv("../data/wnba_clean2.csv")
wnba.head()
# Out:
#               Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 0    Aerial Powers  DAL    F     183      71  21.200991          US
# 1      Alana Beard   LA  G/F     185      73  21.329438          US
# 2     Alex Bentley  CON    G     170      69  23.875433          US
# 3  Alex Montgomery  SAN  G/F     185      84  24.543462          US
# 4     Alexis Jones  MIN    G     175      78  25.469388          US
#
#            Birthdate  Age         College  Experience  Games Played  MIN  FGM  \
# 0   January 17, 1994   23  Michigan State           2             8  173   30
# 1       May 14, 1982   35            Duke          12            30  947   90
# 2   October 27, 1990   26      Penn State           4            26  617   82
# 3  December 11, 1988   28    Georgia Tech           6            31  721   75
# 4     August 5, 1994   23          Baylor           0            24  137   16
#
#    FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  DREB  REB  AST  STL  BLK  \
# ...

# %%
wnba[wnba["Team"]=="MIN"].describe()
# Out:
#            Height     Weight        BMI        Age  Experience  Games Played  \
# count   11.000000  11.000000  11.000000  11.000000   11.000000     11.000000
# mean   183.090909  80.272727  23.903961  30.545455    9.000000     26.454545
# std      8.926976   8.787388   1.415895   4.480260    5.585696      4.009081
# min    170.000000  63.000000  21.220009  23.000000    0.000000     17.000000
# 25%    175.000000  76.000000  23.379517  26.500000    5.500000     25.000000
# 50%    183.000000  78.000000  23.893259  32.000000   10.000000     29.000000
# 75%    188.000000  86.000000  24.978725  34.500000   14.000000     29.000000
# max    198.000000  96.000000  25.469388  35.000000   15.000000     30.000000
#
#               MIN         FGM         FGA        FG%        3PM         3PA  \
# count   11.000000   11.000000   11.000000  11.000000  11.000000   11.000000
# mean   569.818182   96.000000  206.090909  44.445455  18.909091   51.181818
# ...

# %%
wnba[wnba["Team"]=="MIN"]
# Out:
#                  Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 4        Alexis Jones  MIN    G     175      78  25.469388          US
# 67        Jia Perkins  MIN    G     173      75  25.059307          US
# 88     Lindsay Whalen  MIN    G     175      78  25.469388          US
# 93         Maya Moore  MIN    F     183      80  23.888441          US
# 99     Natasha Howard  MIN    F     188      75  21.220009          US
# 105  Plenette Pierson  MIN  F/C     188      88  24.898144          US
# 109  Rebekkah Brunson  MIN    F     188      84  23.766410          US
# 110  Renee Montgomery  MIN    G     170      63  21.799308          US
# 116  Seimone Augustus  MIN  G/F     183      77  22.992624          US
# 130     Sylvia Fowles  MIN    C     198      96  24.487297          US
# 133     Temi Fagbenle  MIN    C     193      89  23.893259          UK
#
#              Birthdate  Age              College  Experience  Games Played  \
# ...

# %%
wnba.describe()
# Out:
#            Height      Weight         BMI         Age  Experience  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000
# mean   184.612676   78.978873   23.091214   27.112676    4.880282
# std      8.698128   10.996110    2.073691    3.667180    4.002627
# min    165.000000   55.000000   18.390675   21.000000    0.000000
# 25%    175.750000   71.500000   21.785876   24.000000    2.000000
# 50%    185.000000   79.000000   22.873314   27.000000    4.000000
# 75%    191.000000   86.000000   24.180715   30.000000    7.000000
# max    206.000000  113.000000   31.555880   36.000000   15.000000
#
#        Games Played          MIN         FGM         FGA         FG%  \
# count    142.000000   142.000000  142.000000  142.000000  142.000000
# mean      24.429577   500.105634   74.401408  168.704225   43.102817
# std        7.075477   289.373393   55.980754  117.165809    9.855199
# min        2.000000    12.000000    1.000000    3.000000   16.700000
# ...

# %%
wnba["PitchAge"] = wnba["Age"]*wnba["MIN"]
team_stats = wnba.pivot_table(index="Team", aggfunc="sum")
team_stats["PitchAge"] = team_stats["PitchAge"]/team_stats["MIN"]
team_stats.sort_values("PitchAge")
# Out:
#         3P%  3PA  3PM  AST  Age  BLK         BMI  DD2  DREB  Experience  \
# Team
# DAL   322.0  533  179  364  296   99  279.558728   15   590          31
# CON   307.4  648  230  571  300   44  296.397926    7   657          38
# SAN   413.3  355  116  547  347   90  295.981006    8   714          50
# ATL   212.8  477  139  559  296  109  247.808144    5   802          57
# WAS   234.6  610  193  505  320  139  269.707454    8   740          62
# NY    230.1  421  140  412  312  120  287.984466   16   800          56
# CHI   259.3  448  173  558  298  150  251.196756   32   757          44
# SEA   314.1  506  179  546  325  138  274.069893   15   835          57
# LA    268.4  450  159  535  342  109  272.484242   21   706          71
# IND   290.4  707  236  518  336   84  272.064662    2   588          68
# PHO   375.9  487  154  554  342  183  268.755569   11   801          60
# MIN   318.6  563  208  652  336  124  262.943575   22   756          99
#
# ...
