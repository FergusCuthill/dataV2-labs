# %%
import pandas as pd
import numpy as np
import re
import os
import pymysql
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from IPython.display import display_html
from multiprocessing import Pool

# %matplotlib inline
pd.set_option('display.max_columns', 50)

# %%
# This function allows displaying of multiple data frames next to eachother. 
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
cred = os.environ.get('SQL')
engine = create_engine('mysql+pymysql://'+cred+'@localhost/books_project')

# %%
bx_books = pd.read_sql("bx_books", con=engine).drop("index", axis=1)
bx_book_r = pd.read_sql("bx_book_r", con=engine).drop("index", axis=1)
amazon32 = pd.read_sql("amazon32", con=engine).drop("index", axis=1)
gr_books_10k = pd.read_sql("gr_books_10k", con=engine).drop("index", axis=1)
gr_books_k = pd.read_sql("gr_books_k", con=engine)

# %%
# Remove 0 ratings as these are not actual ratings. They amount to about 1/3 of the dataset. 
bx_book_r = bx_book_r[bx_book_r["Book-Rating"]!=0]
bx_book_r
# Out:
#          User-ID         ISBN  Book-Rating
# 1         276726   0155061224            5
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# 6         276736   3257224281            8
# 7         276737   0600570967            6
# ...          ...          ...          ...
# 1149773   276704   0806917695            5
# 1149775   276704   1563526298            9
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [433671 rows x 3 columns]

# %% [markdown]
# Count ratings for each rating

# %%
ax = bx_book_r["Book-Rating"].value_counts().sort_index().plot.bar(title="Rating Frequencies", figsize=(10,6), rot=0)
ax.set(xlabel="Individual Rating", ylabel="Frequency")
ax

# %%
# 
bx_br = bx_book_r[["ISBN", "Book-Rating"]].groupby("ISBN").agg(["mean", "count"]).join(bx_books.set_index("ISBN")).dropna()
bx_br.columns = ["Av Rating", "Ratings Count", 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher']
bx_br
# Out:
# C:\Users\fergu\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:618: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)
#             Av Rating  Ratings Count  \
# ISBN
# 0000913154        8.0              1
# 0001046438        9.0              1
# 000104687X        6.0              1
# 0001047213        9.0              1
# 0001047973        9.0              2
# ...               ...            ...
# B0001FZGPI        7.0              1
# B0001FZGRQ        9.0              1
# B0001GMSV2        8.0              2
# B0001I1KOG       10.0              1
# B000234N3A        9.0              1
#
#                                                    Book-Title  \
# ISBN
# 0000913154  The Way Things Work: An Illustrated Encycloped...
# 0001046438                                               Liar
# 000104687X  T.S. Eliot Reading \The Wasteland\" and Other ...
# 0001047213                                   The Fighting Man
# 0001047973                                    Brave New World
# ...                                                       ...
# B0001FZGPI                          The Bonesetter's Daughter
# B0001FZGRQ                          The Clan of the Cave Bear
# B0001GMSV2                                            Find Me
# B0001I1KOG       New York Public Library Literature Companion
# B000234N3A                                              Fraud
#
#                               Book-Author Year-Of-Publication  \
# ISBN
# 0000913154  C. van Amerongen (translator)                1967
# 0001046438                    Stephen Fry                   0
# 000104687X                     T.S. Eliot                1993
# 0001047213                 Gerald Seymour                1993
# 0001047973                  Aldous Huxley                1999
# ...                                   ...                 ...
# B0001FZGPI                        Amy Tan                2001
# B0001FZGRQ                   Jean M. Auel                2001
# B0001GMSV2                Rosie O'Donnell                2002
# B0001I1KOG        New York Public Library                2001
# B000234N3A                   David Rakoff                2001
#
#                               Publisher
# ISBN
# 0000913154         Simon &amp; Schuster
# 0001046438             Harpercollins Uk
# 000104687X     HarperCollins Publishers
# 0001047213     HarperCollins Publishers
# 0001047973  Trafalgar Square Publishing
# ...                                 ...
# B0001FZGPI             Putnam Pub Group
# B0001FZGRQ       Crown Publishing Group
# B0001GMSV2                 Warner Books
# B0001I1KOG                   Free Press
# B000234N3A                    Doubleday
#
# [149839 rows x 6 columns]

# %%
f, ax = plt.subplots(figsize=(14, 9))
ax.set(xscale="log", xlim=(0.5,1000))
ax.set_title("Ratings Count vs Average Rating")
sns.scatterplot("Ratings Count", "Av Rating", data=bx_br, ax=ax)

# %%
# Calculate an adjusted rating 2 stds from the mean of the sample
def LCB_rating(ISBN):
    rat = bx_book_r[bx_book_r["ISBN"]==ISBN]["Book-Rating"]
    return np.mean(rat)-2*np.std(rat)

bx_br["LCB rating"] = bx_br.index.map(lambda x: LCB_rating(x))

# %%
# Calculate Standard Deviation of all ratings
votstd = np.std(bx_book_r["Book-Rating"])

# %%
# The following are various attempts to define functions that will modify the rating scores to score higher for books with more ratings. 
bx_br["Mod rating"] = bx_br["Av Rating"] - 2*votstd/bx_br["Ratings Count"]

# %%
bx_br["Mod rating"] = bx_br["Av Rating"]*bx_br["Ratings Count"]**0.05

# %%
bx_br["Mod rating"] = (bx_br["Av Rating"] - 2*votstd/bx_br["Ratings Count"])*bx_br["Ratings Count"]**0.02

# %%
f, ax = plt.subplots(figsize=(14, 9))
ax.set(xscale="log", xlim=(0.5,1000))
ax.set_title("Ratings Count vs Modified Rating")
sns.scatterplot("Ratings Count", "Mod rating", data=bx_br, ax=ax)

# %%
ax = bx_br[bx_br["Ratings Count"]>10]["Av Rating"].hist(bins=20,figsize=(10,6))
ax.set(xlabel="Book Rating", ylabel="Frequency")
ax.grid(False)
ax

# %%
bx_br.nlargest(20, "Mod rating")
# Out:
#             Av Rating  Ratings Count  \
# ISBN
# 0439425220   9.869565             23
# 0618002235   9.720000             25
# 0345339738   9.402597             77
# 0439139597   9.262774            137
# 0060256656   9.750000             20
# 0836213319   9.923077             13
# 1888054557  10.000000             11
# 0836220889   9.583333             24
# 0394800389   9.785714             14
# 043935806X   9.033981            206
# 059035342X   8.939297            313
# 0836218221   9.600000             20
# 0439136369   9.082707            133
# 0743454529   9.545455             22
# 0140143505   9.464286             28
# 0439136350   9.035461            141
# 0394800893  10.000000              8
# 0446310786   8.943925            214
# 0618002243   9.625000             16
# 0345339711   9.120482             83
#
#                                                    Book-Title  \
# ISBN
# 0439425220  Harry Potter and the Chamber of Secrets Postca...
