# %% [markdown]
# # Descriptive Statistics Review

# %% [markdown]
# ## Before you start:
#
# - Read the README.md file
# - Comment as much as you can
# - Happy learning!

# %% [markdown]
# ## Context

# %% [markdown]
# ![img](./diamonds.jpg)

# %% [markdown]
# In this lab we are going to work with data to understand the characteristics of a diamond that are most likely to influence its price. In this first part of the lab, we will explore and clean our data.
#
# The dataset we will be using is comprised of approximately 54k rows and 11 different columns. As always, a row represents a single observation (in this case a diamond) and each of the columns represent a different feature of a diamond.
#
# The following codebook was provided together with the dataset to clarify what each column represents:

# %% [markdown]
# | Column  | Description  |
# |---|---|
# | Price  | Price in US dollars (326-18,823)  |
# | Carat  | Weight of the diamond (0.2--5.01)  |
# | Cut  | Quality of the cut (Fair, Good, Very Good, Premium, Ideal)  |
# | Color  | Diamond colour, from J (worst) to D (best)  |
# | Clarity  | A measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))   |
# | x  | Length in mm (0--10.74)  |
# | y  | Width in mm (0--58.9)  |
# | z  | Depth in mm (0--31.8)  |
# | Depth  | Total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)  |
# | Table  | Width of top of diamond relative to widest point (43--95)  |

# %% [markdown]
# ## Libraries
# Pandas and numpy will be needed for the analysis of the data. Don't worry about the seaborn and matplotlib import at the moment, you will learn more about them next week, but we will be using some of their functionalities.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# First import the data from the .csv file provided and assign it to a variable named `diamonds` and drop the column with the index.

# %%
#your code here
diamonds = pd.read_csv("diamonds.csv").drop("Unnamed: 0", axis=1)

# %% [markdown]
# # 1. Taking the first look at the data.
# Let's see how the data looks by using pandas methods like `head()`, `info()` and `describe()`.
#
# **First, use the `head` method.**

# %%
#your code here
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# We can see the first 5 rows of the dataset using the `head` method. This by itself doesn't tell us much about the data that we have, but we can have a first look at the features (columns) and some of the values that each one takes.
#
# **What do you see? Make some comments about the values you see in each column, comparing them with the codebook. Is that what you would expect for these variables?**

# %%
#your code here
"""
There are 7 numerical columns (plus the index) and 3 text columns. Some variation but hard to make many assumptions based
on this
"""
# Out:
# '\nThere are 7 numerical columns (plus the index) and 3 text columns. Some variation but hard to make many assumptions based\non this\n'

# %% [markdown]
# It is very important to know the amount of data we have, because everything will depend on that, from the quality of the analysis to the choice of our infrastracture.
#
# **Check the shape of the data**

# %%
#your code here
diamonds.shape
# Out:
# (53940, 10)

# %% [markdown]
# The `clarity` column is confusing because we are not diamond experts. Let's create a new column with a new scale that is more understandable for us.
#
# **Create a new column with numbers from 0 to 7. The lowest would be 0 with value `I1` and the greatest 7 with value `IF`**

# %%
#your code here
diamonds["clarity_n"] = diamonds["clarity"].map({"I1":0, "SI2":1, "SI1":2, "VS2":3, "VS1":4, "VVS2":5, "VVS1":6, "IF":7})

# %% [markdown]
# It makes sense to do the same with the `color` column.
#
# **Do the same with values from 0 to 6. Read the codebook to see the match**

# %%
#your code here
diamonds = diamonds.rename({"color":"colour"}, axis =1)
diamonds["colour_n"] = diamonds["colour"].map(lambda a: 74-ord(a))
diamonds
# Out:
#        carat        cut colour clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal      E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium      E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good      E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium      I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good      J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...    ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal      D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good      D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good      D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium      H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal      D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        clarity_n  colour_n
# 0              1         5
# 1              2         5
# 2              4         5
# 3              3         1
# 4              1         0
# ...          ...       ...
# 53935          2         6
# 53936          2         6
# 53937          2         6
# 53938          1         2
# 53939          1         6
#
# [53940 rows x 12 columns]

# %% [markdown]
# With the `info` method, we can see the features of the dataset, and the amount of observations (rows) that have a non-null value and the types of the features.
#
# **Now use the `info` method and comparing with the shape, comment on what you see**

# %%
#your code here
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   carat      53940 non-null  float64
#  1   cut        53940 non-null  object
#  2   colour     53940 non-null  object
#  3   clarity    53940 non-null  object
#  4   depth      53940 non-null  float64
#  5   table      53940 non-null  float64
#  6   price      53940 non-null  int64
#  7   x          53940 non-null  float64
#  8   y          53940 non-null  float64
#  9   z          53940 non-null  float64
#  10  clarity_n  53940 non-null  int64
#  11  colour_n   53940 non-null  int64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 4.9+ MB

# %% [markdown]
# In the last line of the info output, you have some information about the types of the columns. As you know, it is a good idea to check if the types of each column is what you expect. If a column has the right type, we will be able to do all the operations that we want to do.
#
# For instance, if we have a column that is a `date` with a `string` format, we will have the data but we won't be able to do a simple operation, such as format the date the way that we would like.
#
# Changing the data type to the one we needs can help us to solve a lot of problems in our data.
#
# **Check the types of each column and comment if it matches with the expected**

# %%
#your code here
# Each dtype appears to be reasonable.

# %% [markdown]
# # 2. A deeper look: checking the basic statistics.
#
# The `describe` method gives us an overview of our data. From here we can see all the descriptive metrics for our variables.
#
# **Use the `describe` method and comment on what you see**

# %%
#your code and comments here
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z     clarity_n      colour_n
# count  53940.000000  53940.000000  53940.000000  53940.000000
# mean       5.734526      3.538734      3.051020      3.405803
# std        1.142135      0.705699      1.647136      1.701105
# min        0.000000      0.000000      0.000000      0.000000
# 25%        4.720000      2.910000      2.000000      2.000000
# 50%        5.710000      3.530000      3.000000      3.000000
# 75%        6.540000      4.040000      4.000000      5.000000
# max       58.900000     31.800000      7.000000      6.000000

# %% [markdown]
# You have probably noticed that the columns x, y and z have a minimum value of 0. This means that there are one or more rows (or observations) in our dataset that are supposedly representing a diamond that has lenght, width or depth of 0. Considering that we're talking about a physical object, this is impossible!
#
# Now let's proceed to check the rows that have a value of 0 in any of the x, y or z columns. By doing this we want to check if the data we are missing can be obtained using the data that we do have.
#
# **Check the columns with `x`, `y` and `z` with value 0 in all of them and comment what you see**

# %%
#your code here
impossible_objects = diamonds[(diamonds["x"] == 0) | (diamonds["y"] == 0) | (diamonds["z"] == 0)]
impossible_objects
# Out:
#        carat        cut colour clarity  depth  table  price     x     y    z  \
# 2207    1.00    Premium      G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium      H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium      G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium      F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good      G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal      F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good      H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal      G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair      G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium      H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal      G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# 26123   2.25    Premium      I     SI1   61.3   58.0  15397  8.52  8.42  0.0
# 26243   1.20    Premium      D    VVS1   62.1   59.0  15686  0.00  0.00  0.0
# 27112   2.20    Premium      H     SI1   61.2   59.0  17265  8.42  8.37  0.0
# 27429   2.25    Premium      H     SI2   62.8   59.0  18034  0.00  0.00  0.0
# 27503   2.02    Premium      H     VS2   62.7   53.0  18207  8.02  7.95  0.0
# 27739   2.80       Good      G     SI2   63.8   58.0  18788  8.90  8.85  0.0
# 49556   0.71       Good      F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 49557   0.71       Good      F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 51506   1.12    Premium      G      I1   60.4   59.0   2383  6.71  6.67  0.0
#
#        clarity_n  colour_n
# 2207           1         3
# 2314           0         2
# 4791           1         3
# 5471           1         4
# 10167          0         3
# 11182          1         4
# 11963          3         2
# 13601          3         3
# 15951          4         3
# 24394          1         2
# 24520          3         3
# 26123          2         1
# 26243          6         6
# 27112          2         2
# 27429          1         2
# 27503          3         2
# 27739          1         3
# 49556          1         4
# 49557          1         4
# 51506          0         3

# %% [markdown]
# As you can see, we have 20 rows that have a value of 0 in some or all the aforementioned columns.
# Most of them (12) are missing the z value, which we can obtain using the columns depth, x and y.
#
# 20 rows with issues represent just 0.03% of our data (20 out of 53940) so it wouldn't be a big deal to remove them. Still, lets try to keep all the data we have.
#
# For those 12 rows, we will create a function that applies the formula given in the codebook and get the value of z. We will drop the other rows (8), since they are missing all 3 values or 2 of them.
#
# **Create a function named `calculate_z` that applies the function in the codebook to one single row you give to the function**

# %%
#your code here
def calculate_z(row):
    if (row.z == 0.0) & (row.y != 0.0) & (row.x != 0.0):
        return row.depth*(row.x+row.y)/200
    else:
        return row.z

# %% [markdown]
# **Apply it just to the rows with incorrect values**

# %%
#your code here
diamonds["z"] = diamonds.apply(lambda row: calculate_z(row), axis = 1)
diamonds
# Out:
#        carat        cut colour clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal      E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium      E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good      E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium      I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good      J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...    ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal      D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good      D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good      D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium      H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal      D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        clarity_n  colour_n
# 0              1         5
# 1              2         5
# 2              4         5
# 3              3         1
# 4              1         0
# ...          ...       ...
# 53935          2         6
# 53936          2         6
# 53937          2         6
# 53938          1         2
# 53939          1         6
#
# [53940 rows x 12 columns]

# %% [markdown]
# If we leave the other 8 values as they are, it would negatively affect our analysis, because these are data that do not make logical sense. Therefore it is better to consider those values as NaN values, since they are probably the result of a mistake or error during process of measuring and storing these values in a dataset.
#
# To replace them we can use the pandas .replace() method and np.NaN.
#
# **Replace the zero values in the `z` column for a NaN**

# %%
#your code here
# Felt it made sense to do this for x and y too
diamonds["x"] = diamonds["x"].replace(to_replace = 0.0, value = np.nan)
diamonds["y"] = diamonds["y"].replace(to_replace = 0.0, value = np.nan)
diamonds["z"] = diamonds["z"].replace(to_replace = 0.0, value = np.nan)
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   carat      53940 non-null  float64
#  1   cut        53940 non-null  object
#  2   colour     53940 non-null  object
#  3   clarity    53940 non-null  object
#  4   depth      53940 non-null  float64
#  5   table      53940 non-null  float64
#  6   price      53940 non-null  int64
#  7   x          53932 non-null  float64
#  8   y          53933 non-null  float64
#  9   z          53932 non-null  float64
#  10  clarity_n  53940 non-null  int64
#  11  colour_n   53940 non-null  int64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 4.9+ MB

# %% [markdown]
# ----
# # Bonus: check the new z values
# Since we need to be 100% sure of our data, let's create a function that validates our z. To do so, we will use the same formula, but this time we will calculate the value of depth with the new value assigned to z.
#
# **Create a function named `validate_z` that compares the `z`  in cells above with the one thrown by the formula and run it with the rows you changed in the cells above**

# %%
#your code here

# %% [markdown]
# Let's check the data again with the `describe()` method.

# %% [markdown]
# The minimum value for x, y and z should now be a positive number, as it should be for the physical measurements of an object.

# %% [markdown]
# Let's finish by checking for NaN values in the data. Since we introduced them ourselves using 'replace', we will surely find some, but there may be more that are unrelated to the x, y and z columns. Checking NaNs is a fundamental part of data cleaning and it's always better to do this kind of operations before proceeding with analysis.
#
# **Check how many NaNs do you have, comment what you would do with those values, and then do so**

# %%
#your code here

# %% [markdown]
# # 3. Checking for outliers
# Now we are going to revisit the summary table to check for outliers.
#
# **Use the `describe` method again and comment on what you see. After that, check if you have any outliers**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53932.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.732007
# std        0.474011      1.432621      2.234491   3989.439738      1.119670
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z     clarity_n      colour_n
# count  53933.000000  53932.000000  53940.000000  53940.000000
# mean       5.735270      3.540265      3.051020      3.405803
# std        1.140339      0.702667      1.647136      1.701105
# min        3.680000      1.070000      0.000000      0.000000
# 25%        4.720000      2.910000      2.000000      2.000000
# 50%        5.710000      3.530000      3.000000      3.000000
# 75%        6.540000      4.040000      4.000000      5.000000
# max       58.900000     31.800000      7.000000      6.000000

# %%
#your comments here

# Return the largest 30 values from each numerical column to look for outliers
num_cols = ["carat", "depth", "table", "price", "x", "y", "z", "clarity_n", "colour_n"]
diamonds2 = pd.DataFrame([list(diamonds.nlargest(30,col)[col]) for col in num_cols], index = num_cols).transpose()
diamonds2
# There are a couple of values in the y and z columns much higher than the others however, these are listed in the
# codebook as the max values for these categories. Unclear if this is acceptable limits or just max/min. Will leave for now
# Also a large value in table but again, this is within the limits in the codebook. Note I wrote this before looking at
# the later exercises which do identify the x and y values as outliers.
# Out:
#     carat  depth  table    price      x      y      z  clarity_n  colour_n
# 0    5.01   79.0   95.0  18823.0  10.74  58.90  31.80        7.0       6.0
# 1    4.50   79.0   79.0  18818.0  10.23  31.80   8.06        7.0       6.0
# 2    4.13   78.2   76.0  18806.0  10.14  10.54   6.98        7.0       6.0
# 3    4.01   73.6   73.0  18804.0  10.02  10.16   6.72        7.0       6.0
# 4    4.01   72.9   73.0  18803.0  10.01  10.10   6.43        7.0       6.0
# 5    4.00   72.2   73.0  18797.0  10.00   9.94   6.38        7.0       6.0
# 6    3.67   71.8   73.0  18795.0   9.86   9.94   6.31        7.0       6.0
# 7    3.65   71.6   71.0  18795.0   9.66   9.85   6.27        7.0       6.0
# 8    3.51   71.6   70.0  18791.0   9.65   9.81   6.24        7.0       6.0
# 9    3.50   71.3   70.0  18791.0   9.54   9.63   6.17        7.0       6.0
# 10   3.40   71.2   70.0  18788.0   9.53   9.59   6.16        7.0       6.0
# 11   3.24   71.0   70.0  18787.0   9.51   9.48   6.13        7.0       6.0
# 12   3.22   70.8   70.0  18784.0   9.49   9.46   6.03        7.0       6.0
# 13   3.11   70.8   70.0  18781.0   9.44   9.42   6.03        7.0       6.0
# 14   3.05   70.6   70.0  18780.0   9.44   9.40   5.98        7.0       6.0
# 15   3.04   70.6   70.0  18779.0   9.44   9.38   5.97        7.0       6.0
# 16   3.04   70.6   70.0  18777.0   9.42   9.38   5.92        7.0       6.0
# 17   3.02   70.5   69.0  18768.0   9.42   9.37   5.91        7.0       6.0
# 18   3.01   70.2   69.0  18766.0   9.41   9.34   5.90        7.0       6.0
# 19   3.01   70.2   69.0  18760.0   9.38   9.32   5.90        7.0       6.0
# 20   3.01   70.2   69.0  18759.0   9.36   9.31   5.86        7.0       6.0
# 21   3.01   70.1   69.0  18757.0   9.35   9.31   5.85        7.0       6.0
# 22   3.01   70.1   69.0  18756.0   9.32   9.26   5.79        7.0       6.0
# 23   3.01   70.0   69.0  18745.0   9.30   9.25   5.77        7.0       6.0
# 24   3.01   69.9   69.0  18741.0   9.26   9.22   5.77        7.0       6.0
# 25   3.01   69.8   69.0  18741.0   9.25   9.20   5.77        7.0       6.0
# 26   3.01   69.8   68.0  18741.0   9.24   9.19   5.76        7.0       6.0
# 27   3.01   69.8   68.0  18736.0   9.23   9.14   5.75        7.0       6.0
# 28   3.01   69.7   68.0  18735.0   9.17   9.13   5.73        7.0       6.0
# 29   3.01   69.7   68.0  18731.0   9.15   9.13   5.72        7.0       6.0

# %%
diamonds3 = pd.DataFrame([list(diamonds.nsmallest(30,col)[col]) for col in num_cols], index = num_cols).transpose()
diamonds3
# Having removed the 0s from the x,y and z columns there is no indication of outliers.
# Out:
#     carat  depth  table  price     x     y     z  clarity_n  colour_n
# 0    0.20   43.0   43.0  326.0  3.73  3.68  1.07        0.0       0.0
# 1    0.20   43.0   44.0  326.0  3.73  3.71  1.41        0.0       0.0
# 2    0.20   44.0   49.0  327.0  3.74  3.71  1.53        0.0       0.0
# 3    0.20   50.8   49.0  334.0  3.76  3.72  2.06        0.0       0.0
# 4    0.20   51.0   50.0  335.0  3.77  3.73  2.24        0.0       0.0
# 5    0.20   52.2   50.0  336.0  3.79  3.75  2.25        0.0       0.0
# 6    0.20   52.3   50.1  336.0  3.79  3.77  2.26        0.0       0.0
# 7    0.20   52.7   51.0  337.0  3.81  3.77  2.27        0.0       0.0
# 8    0.20   53.0   51.0  337.0  3.81  3.78  2.28        0.0       0.0
# 9    0.20   53.1   51.0  338.0  3.81  3.78  2.29        0.0       0.0
# 10   0.20   53.2   51.0  339.0  3.82  3.78  2.30        0.0       0.0
# 11   0.20   53.2   51.0  340.0  3.82  3.78  2.30        0.0       0.0
# 12   0.21   53.3   51.0  342.0  3.83  3.78  2.31        0.0       0.0
# 13   0.21   53.4   51.0  344.0  3.83  3.80  2.31        0.0       0.0
# 14   0.21   53.8   51.0  345.0  3.83  3.81  2.31        0.0       0.0
# 15   0.21   54.0   51.0  345.0  3.84  3.82  2.31        0.0       0.0
# 16   0.21   54.2   51.6  348.0  3.84  3.83  2.31        0.0       0.0
# 17   0.21   54.2   52.0  351.0  3.84  3.84  2.31        0.0       0.0
# 18   0.21   54.3   52.0  351.0  3.84  3.84  2.32        0.0       0.0
# 19   0.21   54.4   52.0  351.0  3.85  3.84  2.32        0.0       0.0
# 20   0.21   54.6   52.0  351.0  3.85  3.84  2.32        0.0       0.0
# 21   0.22   54.7   52.0  352.0  3.85  3.84  2.33        0.0       0.0
# 22   0.22   55.0   52.0  353.0  3.85  3.85  2.33        0.0       0.0
# 23   0.22   55.0   52.0  353.0  3.85  3.85  2.33        0.0       0.0
# 24   0.22   55.1   52.0  353.0  3.85  3.85  2.33        0.0       0.0
# 25   0.22   55.1   52.0  354.0  3.86  3.85  2.33        0.0       0.0
# 26   0.23   55.1   52.0  355.0  3.86  3.86  2.33        0.0       0.0
# 27   0.23   55.2   52.0  357.0  3.86  3.86  2.33        0.0       0.0
# 28   0.23   55.2   52.0  357.0  3.86  3.86  2.34        0.0       0.0
# 29   0.23   55.2   52.0  357.0  3.86  3.87  2.34        0.0       0.0

# %% [markdown]
# To manage these outliers, we are going to filter our DataFrame, we're going to take all the values that have a price higher than the 75th percentile.
#
# **Look for that quantile and filter the dataframe to clearly see the outliers. What do you think?**

# %%
#your code here
q_price = diamonds["price"].quantile(0.75)
diamonds[diamonds["price"] >= q_price]
# When this says take, are we taking them forwards, taking them away or just taking them to have a look? 
# Fancy diamonds are expensive. I would expect a right skew distribution here so having some large values is not
# unreasonable. If anything, I'm surprised how grouped that higher prices are.
# Out:
#        carat        cut colour clarity  depth  table  price     x     y     z  \
# 12765   1.07      Ideal      E     SI2   62.2   55.0   5325  6.54  6.58  4.08
# 12766   1.11      Ideal      H     SI1   60.6   59.0   5325  6.75  6.71  4.08
# 12767   1.14    Premium      G     SI1   62.2   58.0   5326  6.64  6.70  4.15
# 12768   1.07    Premium      H     VS2   62.1   59.0   5327  6.52  6.56  4.06
# 12769   1.33  Very Good      J     SI1   64.0   53.0   5327  6.93  7.01  4.46
# ...      ...        ...    ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good      H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal      G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal      G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good      G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium      I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
#        clarity_n  colour_n
# 12765          1         5
# 12766          2         2
# 12767          2         3
# 12768          3         2
# 12769          2         0
# ...          ...       ...
# 27745          2         2
# 27746          1         3
# 27747          7         3
# 27748          2         3
# 27749          3         1
#
# [13485 rows x 12 columns]

# %% [markdown]
# Our dataset is really big and the outliers are really far apart from the rest of the values. To see this more clearly we will use a boxplot, which plots the median, 25th and 75th quartile, the maximum and minimum, as well as any outliers.

# %%
#Run this code
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds.y, ax=ax[0])
sns.boxplot(y=diamonds.z, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# Now we can see that all the values are within an acceptable range, but we have 2 big outliers in y and 1 in z. Now we know that our max values for y should be around 10 and the values for z should be around 6, so let's filter our dataset to find values higher than 10 in it.

# %%
#your code here
filtered = diamonds[(diamonds["y"] >= 10) | (diamonds["z"] >= 10)]
filtered
# Out:
#        carat        cut colour clarity  depth  table  price      x      y  \
# 24067   2.00    Premium      H     SI2   58.9   57.0  12210   8.09  58.90
# 25998   4.01    Premium      I      I1   61.0   61.0  15223  10.14  10.10
# 27415   5.01       Fair      J      I1   65.5   59.0  18018  10.74  10.54
# 27630   4.50       Fair      J      I1   65.8   58.0  18531  10.23  10.16
# 48410   0.51  Very Good      E     VS1   61.8   54.7   1970   5.12   5.15
# 49189   0.51      Ideal      E     VS1   61.8   55.0   2075   5.15  31.80
#
#            z  clarity_n  colour_n
# 24067   8.06          1         2
# 25998   6.17          0         1
# 27415   6.98          0         0
# 27630   6.72          0         0
# 48410  31.80          4         5
# 49189   5.12          4         5

# %% [markdown]
# Now that we have found the outlier, let's use the function we defined earlier to correct this value. First, we need to change the value to 0 (because that's how we defined the function before) and then we will apply it.
#
# **Apply `calculate_z` for the row with the outlier**

# %%
#your code here
diamonds['z'] = np.where(diamonds['z'] > 10, 0, diamonds['z'])
diamonds["z"] = diamonds.apply(lambda row: calculate_z(row), axis = 1)

# %% [markdown]
# Let's check if we actually corrected the outlier.

# %%
diamonds.loc[48410]
# Out:
# carat             0.51
# cut          Very Good
# colour               E
# clarity            VS1
# depth             61.8
# table             54.7
# price             1970
# x                 5.12
# y                 5.15
# z              3.17343
# clarity_n            4
# colour_n             5
# Name: 48410, dtype: object

# %% [markdown]
# Cool! Now let's validate our new `z`. We will check if we obtain the same value of depth using our validate function. If the formula applies, this means could approximate the real value of `z`.
#
# **Apply `validate_z` to the row used earlier**

# %%
#your code here

# This was a bonus question to make this function. I hope to have time to do this over the weekend but until I've done
# the bonus, I'm not sure I can do this.

# %% [markdown]
# Now let's do the same for `y`. First, let's filter the DataFrame to find the outliers. We said that the maximum values should be around 10, so let's check what are the values above 10.
#
# **Check the values greater than 10 in the `y` column**

# %%
#your code here
diamonds[(diamonds["y"] >= 10)]
# Out:
#        carat      cut colour clarity  depth  table  price      x      y     z  \
# 24067   2.00  Premium      H     SI2   58.9   57.0  12210   8.09  58.90  8.06
# 25998   4.01  Premium      I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 27415   5.01     Fair      J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair      J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 49189   0.51    Ideal      E     VS1   61.8   55.0   2075   5.15  31.80  5.12
#
#        clarity_n  colour_n
# 24067          1         2
# 25998          0         1
# 27415          0         0
# 27630          0         0
# 49189          4         5

# %% [markdown]
# We can clearly see that the 31.8 in row 49189 is an outlier for the y value. Also, we can see that the 58.9 value for `y` in row 24067 is actually its depth, so it was a mistake when they introduced the data. Let's create a function to fix these outliers.
#
# **Create a function named `calculate_y` to calculate `y` using `z` and `x` the same way you did above**

# %%
#your code here

def calculate_y(row):
    if row.y > 15:
        return 200*row.z/row.depth - row.x
    else:
        return row.y    

    
diamonds["y"] = diamonds.apply(lambda row: calculate_z(row), axis = 1)
diamonds.loc[24067]
# Out:
# carat              2
# cut          Premium
# colour             H
# clarity          SI2
# depth           58.9
# table             57
# price          12210
# x               8.09
# y               8.06
# z               8.06
# clarity_n          1
# colour_n           2
# Name: 24067, dtype: object

# %% [markdown]
# We will check the rows that had an outlier in `y`, to check that the values were changed.
#
# **Check those rows (also validating with your function) and comment what you see**

# %% [markdown]
# Now that we have corrected or dropped all of our outliers, lets plot another box plot to double check.

# %%
#Run this code
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds.y, ax=ax[0])
sns.boxplot(y=diamonds.z, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# **What do you think? Are these values more reasonable?**

# %%
#your thoughts here
# Yes, these appear more reasonable. Still values outside the whiskers but they are not unreasonable.

# %% [markdown]
# **Once you are happy with your cleaning, save the cleaned data and continue to csv. Your new csv should be named ``diamonds_clean``**

# %%
#your code here
diamonds.to_csv("diamonds_clean.csv", index = False)
