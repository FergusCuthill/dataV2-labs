# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
# response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page=1&per_page=100').json()
# flattened_data = json_normalize(response)
# response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page=2&per_page=100').json()
# flattened_data = flattened_data.append(json_normalize(response)).reset_index()
# flattened_data


# Iteration method

i=1
flattened_data = pd.DataFrame()
while i != 0:
    api = 'https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page='+str(i)+'&per_page=100'
    response = pd.json_normalize(requests.get(api).json())
    flattened_data = flattened_data.append(response)
    i += 1
    if len (response) < 100:
        i = 0
        
flattened_data = flattened_data.reset_index()
flattened_data
# Out:
#      index         id                           node_id         name  \
# 0        0  261791698  MDEwOlJlcG9zaXRvcnkyNjE3OTE2OTg=  dataV2-labs
# 1        1  261162998  MDEwOlJlcG9zaXRvcnkyNjExNjI5OTg=  dataV2-labs
# 2        2  261150300  MDEwOlJlcG9zaXRvcnkyNjExNTAzMDA=  dataV2-labs
# 3        3  261144946  MDEwOlJlcG9zaXRvcnkyNjExNDQ5NDY=  dataV2-labs
# 4        4  261144477  MDEwOlJlcG9zaXRvcnkyNjExNDQ0Nzc=  dataV2-labs
# ..     ...        ...                               ...          ...
# 101      1  215970459  MDEwOlJlcG9zaXRvcnkyMTU5NzA0NTk=  dataV2-labs
# 102      2  215567399  MDEwOlJlcG9zaXRvcnkyMTU1NjczOTk=  dataV2-labs
# 103      3  215323533  MDEwOlJlcG9zaXRvcnkyMTUzMjM1MzM=  dataV2-labs
# 104      4  215323405  MDEwOlJlcG9zaXRvcnkyMTUzMjM0MDU=  dataV2-labs
# 105      5  215267431  MDEwOlJlcG9zaXRvcnkyMTUyNjc0MzE=  dataV2-labs
#
#                      full_name  private  \
# 0      llopisaleix/dataV2-labs    False
# 1        Mingiziem/dataV2-labs    False
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here
lang = list(flattened_data["language"])
print(lang)
# Out:
# ['Jupyter Notebook', None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', None, None, 'Jupyter Notebook', 'Jupyter Notebook', None, None, None, None, None, None, None, 'Jupyter Notebook', None, None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', None, None, None, None, None, None, 'Jupyter Notebook', None, None, 'Jupyter Notebook', None, None, None, 'Jupyter Notebook', 'Jupyter Notebook', None, None, 'Jupyter Notebook', None, 'Jupyter Notebook', None, None, None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', None, 'AGS Script', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Ju
# ...

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
# response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?page=1&per_page=100&since=2019-10-01T00:00:00Z&until=2019-11-01T00:00:00Z').json()
# flattened_data = json_normalize(response)
# response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?page=2&per_page=100&since=2019-10-01T00:00:00Z&until=2019-11-01T00:00:00Z').json()
# flattened_data = flattened_data.append(json_normalize(response)).reset_index()
# flattened_data

i=1
flattened_data = pd.DataFrame()
while i != 0:
    api = ('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?page='+str(i)+
           '&per_page=100&since=2019-10-01T00:00:00Z&until=2019-11-01T00:00:00Z')
    response = pd.json_normalize(requests.get(api).json())
    flattened_data = flattened_data.append(response)
    i += 1
    if len (response) < 100:
        i = 0
        
flattened_data = flattened_data.reset_index()
flattened_data
# Out:
#      index                                       sha  \
# 0        0  37e0b0681ff829d1c9f4a542631229efe7d577ff
# 1        1  d9da31ef64900ad297d5d811d4f9c45e66fa8e8f
# 2        2  957cd5b2250076833fce0f363b42b4a77660e4eb
# 3        3  48503eb5aff61da2e7c1fdd55f3f7e407360ad29
# 4        4  a0cc914495a7e137e298cd6f5d47948b5cf64807
# ..     ...                                       ...
# 137     37  14a5e391ed75af39a77ddaee8709f56c2477742b
# 138     38  b76981fcbd5353a81f1a6ff8167aaf0f7db6281a
# 139     39  07c5db0ea09dc8d3b817e7a73e67c7d183590f53
# 140     40  601c36d033364b0b98d2cf59c7e47be0961c9db5
# 141     41  4d5a0bc47433d02d5568a399162d45b5ff4420ac
#
#                                                node_id  \
# 0    MDY6Q29tbWl0MjEzNjQxMTcwOjM3ZTBiMDY4MWZmODI5ZD...
# 1    MDY6Q29tbWl0MjEzNjQxMTcwOmQ5ZGEzMWVmNjQ5MDBhZD...
# 2    MDY6Q29tbWl0MjEzNjQxMTcwOjk1N2NkNWIyMjUwMDc2OD...
# 3    MDY6Q29tbWl0MjEzNjQxMTcwOjQ4NTAzZWI1YWZmNjFkYT...
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
# Hit the limit so this code is here as I was checking when I could start again
# print(requests.get('https://api.github.com/rate_limit').json())
flattened_data["index"].count()
# Out:
# 142

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
# response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents', auth=(username, token)).json()

# This is as close as I got.
response = requests.get('https://api.github.com/search/code?q=filename:scavengerhunt+repo:ironhack-datalabs/scavenger').json()
response
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'url': 'https://api.github.com/repositories/162375181/contents/15024/.0006.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024/.0006.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
# ...

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
